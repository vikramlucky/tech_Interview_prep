# %% [markdown]
# ![Screen%20Shot%202021-05-01%20at%203.42.49%20PM.png](attachment:Screen%20Shot%202021-05-01%20at%203.42.49%20PM.png)

# %%
def longest_substring_with_k_distinct(str, k):
    uniqueChar = {}
    windowStart = 0
    longestLength = float("-inf")

    for windowEnd in range(len(str)):
        ch = str[windowEnd]

        if ch not in uniqueChar:
            uniqueChar[ch] = 0
        uniqueChar[ch] += 1

        while len(uniqueChar) > k:
            ch = str[windowStart]
            uniqueChar[ch] -= 1
            if uniqueChar[ch] == 0:
                del uniqueChar[ch]
            windowStart += 1
  
        longestLength = max(longestLength, windowEnd - windowStart + 1)

    return longestLength

# %%
print("Length of the longest substring: " + str(longest_substring_with_k_distinct("araaci", 2)))
print("Length of the longest substring: " + str(longest_substring_with_k_distinct("araaci", 1)))
print("Length of the longest substring: " + str(longest_substring_with_k_distinct("cbbebi", 3)))
# Out:
# Length of the longest substring: 4
# Length of the longest substring: 2
# Length of the longest substring: 5
