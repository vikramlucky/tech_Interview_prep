# %% [markdown]
# ![Screen%20Shot%202021-05-01%20at%204.19.13%20PM.png](attachment:Screen%20Shot%202021-05-01%20at%204.19.13%20PM.png)

# %%
def non_repeat_substring(str):
# TODO: Write your code here
    left = 0 
    longestLength = 0
    seenChars = {}
    for right in range(len(str)):
        ch = str[right]

        if ch in seenChars:
            left = max(left, seenChars[ch] + 1)

        seenChars[ch] = right
        longestLength = max(longestLength, right - left + 1)
    return longestLength

# O(n) time and O(k) space or O(1) since 26 english characters

# %%
print("Length of the longest substring: " + str(non_repeat_substring("aabccbb")))
print("Length of the longest substring: " + str(non_repeat_substring("abbbb")))
print("Length of the longest substring: " + str(non_repeat_substring("abccde")))
# Out:
# Length of the longest substring: 3
# Length of the longest substring: 2
# Length of the longest substring: 3
