# %% [markdown]
# ![Screen%20Shot%202021-05-01%20at%203.35.57%20PM.png](attachment:Screen%20Shot%202021-05-01%20at%203.35.57%20PM.png)

# %%
def smallest_subarray_with_given_sum(s, arr):

    windowStart = 0
    minArrLen = float("inf")
    currentSum = 0

    for windowEnd in range(len(arr)):
        currentSum += arr[windowEnd]

        while currentSum >= s:
            minArrLen = min(minArrLen, (windowEnd - windowStart) + 1)
            currentSum -= arr[windowStart]
            windowStart+= 1

    return minArrLen if minArrLen!= float("inf") else 0

# %%
print("Smallest subarray length: " + str(smallest_subarray_with_given_sum(7, [2, 1, 5, 2, 3, 2])))
print("Smallest subarray length: " + str(smallest_subarray_with_given_sum(7, [2, 1, 5, 2, 8])))
print("Smallest subarray length: " + str(smallest_subarray_with_given_sum(8, [3, 4, 1, 1, 6])))
# Out:
# Smallest subarray length: 2
# Smallest subarray length: 1
# Smallest subarray length: 3
